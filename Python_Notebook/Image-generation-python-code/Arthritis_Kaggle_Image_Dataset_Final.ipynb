# %% [markdown]
# ---
# **python code to write 300 prompts to generate texts for images using chatgpt**
#
# ---

# %%
pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import openai
import re

# %%
openai.api_key = "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" # Replace YOUR_API_KEY with your OpenAI API key

# %%
# Define the starting prompt
#prompt = "Generate 10 unique prompts to display only X-ray images of people with knee rheumatoid arthritis. The images should show the knee joint with clear indications of rheumatoid arthritis. Please ensure that the images are of high quality and accurately represent the condition"
#prompt = "Generate 10 different prompts to display only X-ray images of children, men, and women with knee rheumatoid arthritis. The prompt must contain the word X-ray. The images should show the knee joint with clear indications of rheumatoid arthritis. Please ensure that the images are of high quality and accurately represent the condition"

#prompt = "Generate 10 unique prompts to display only X-ray images of people with rheumatoid arthritis on knee. The images should show the knee joint with clear indications of rheumatoid arthritis. Please ensure that the images are of high quality and accurately represent the condition"

#prompt = "Create a set of 10 realistic X-ray images using DALL-E 2 that depict different stages of knee rheumatoid arthritis in patients. Each image should show a different degree of joint inflammation, erosion, and deformity, as well as any associated changes in the surrounding tissues. Use annotations to indicate the specific features of each image, such as the presence of bone spurs, the loss of joint space, or the development of cysts. Consider including images that show the progression of the disease over time, as well as images that illustrate the variation in symptoms and severity that can occur between different patients."

prompt ="Using DALL-E 2, create 10 realistic X-ray images of knee joints affected by rheumatoid arthritis. Show different degrees of joint inflammation, erosion, and deformity, with annotations to indicate specific features visible on an X-ray. Make the images as accurate and realistic as possible, displaying the internal structures of the knee joint."


# Define a list of image types
# image_types = ["a dog", "a cat", "a car", "a mountain", "a beach", "a city skyline",
#                "a forest", "a waterfall", "a flower garden", "a person"]

# Define the number of prompts to generate
num_prompts = 200

# Generate the prompts
prompts = []
for i in range(num_prompts):
    # Select a random image type from the list
    #image_type = image_types[random.randint(0, len(image_types)-1)]
    
    # Create the full prompt
    #full_prompt = prompt + image_type
    full_prompt = prompt
    
    # Use the OpenAI API to generate a text completion for the prompt
    response = openai.Completion.create(
        engine="text-davinci-002",
        prompt=full_prompt,
        max_tokens=1024,
        n=1,
        stop=None,
        temperature=0.7,
    )
    # Extract the generated text from the API response
    text = response.choices[0].text.strip()
    
    # Add the generated text to the list of prompts
    prompts.append(text)

# %%
common_list_of_prompts_h1 = []
for i,string in enumerate(prompts):
  #print(f"prompt --> {i+1}")
  #string = "".join(string.splitlines()).replace("\n", "\n\n")
  string = string.replace("\n","|")
  string = string.replace("||","|")
  #string = string.replace(".|","")
  print(string)
  string_list = string.split("|")[1:]
  #string_list2 = string.split("\n\n")
  #print("string_list")
  #print(string_list)
  
  for j, each_prompt in enumerate(string_list):
   # print(f"\nprompt number {j+1}")
    #print(each_prompt)
    #print(each_prompt.split("."))
    clean_prompt = each_prompt.split(".")
    #print("clean_prompt")
    #print(clean_prompt[1])
    final_prompt = clean_prompt[1]
    #print(f"each prompt {j+1}")
    #print(each_prompt)
    # print(f"clean prompt {j+1}")
    # print(clean_prompt)
    #clean_prompt = each_prompt.replace("\n","")

    common_list_of_prompts_h1.append(final_prompt)
# Out:
# 1. An X-ray image of a healthy knee joint viewed from a 45-degree angle with bright overhead lighting.|2. An X-ray image of a healthy knee joint viewed from a 90-degree angle with bright overhead lighting.|3. An X-ray image of a healthy knee joint viewed from a 135-degree angle with bright overhead lighting.|4. An X-ray image of a healthy knee joint viewed from a 180-degree angle with bright overhead lighting.|5. An X-ray image of a healthy knee joint viewed from a 225-degree angle with bright overhead lighting.|6. An X-ray image of a healthy knee joint viewed from a 270-degree angle with bright overhead lighting.|7. An X-ray image of a healthy knee joint viewed from a 315-degree angle with bright overhead lighting.|8. An X-ray image of a healthy knee joint viewed from a 360-degree angle with bright overhead lighting.|9. An X-ray image of a healthy knee joint viewed from a 45-degree angle with dim overhead lighting.|10. An X-ray image of a healthy knee joint viewed from a 90-degree a
# ...

# %%
len(common_list_of_prompts_h1)
# Out:
# 450

# %%
# Remove duplicates from list
unique_prompts = list(set(common_list_of_prompts_h1))
len(unique_prompts)
# Out:
# 184

# %%
unique_prompts
# Out:
# ['',
#  ' An X-ray image of a healthy knee joint in motion, such as when bending or straightening the leg',
#  ' X-ray image of a healthy knee joint with soft, diffused lighting',
#  ' X-ray image of a healthy knee joint viewed from a 135-degree angle with dim overhead lighting',
#  ' A black and white X-ray image of a healthy knee joint viewed from a 90-degree angle',
#  ' A high-resolution X-ray image of a healthy knee joint viewed from a 45-degree angle with dim overhead lighting',
#  ' A high-resolution X-ray image of a healthy knee joint from a side view',
#  ' An X-ray image of a healthy knee joint viewed from a 90-degree angle with dim lighting',
#  ' An X-ray image of a healthy knee joint, viewed from a 90-degree angle, with natural lighting',
#  ' An X-ray image of a healthy knee joint viewed from a 270-degree angle with bright overhead lighting',
#  ' An X-ray image of a healthy knee joint viewed from a 45-degree angle with natural lighting',
# ...

# %%
common_list_of_prompts = []
for i,string in enumerate(prompts):
  tmp = re.sub(r'\d+\.', '||', string.replace('\n', ' ')).replace('.', '').strip()
  tmp = re.sub(r'^(\|{2})|(\|{2})$', '', tmp).strip().split('||')
  final_prompt = tmp[0].strip()
  common_list_of_prompts.append(final_prompt)

# %%
common_list_of_prompts
# Out:
# ['Joint inflammation causing mild swelling and deformity',
#  'Inflammation of the knee joint, with erosion and deformity of the bones',
#  'Rheumatoid arthritis of the knee joint, showing joint inflammation and erosion',
#  'This X-ray shows a joint with moderate inflammation and some erosion The joint space is narrowed and the bones are deformed',
#  'This X-ray shows mild joint inflammation and erosion in the knee joint There is some deformity of the joint, but it is not severe',
#  'Knee joint with minimal joint inflammation and no erosion or deformity',
#  'Joint inflammation:  There is swelling and inflammation around the joint, as well as deformity of the joint',
#  'Normal knee joint:',
#  'Knee joint with mild joint inflammation and erosion',
#  'Rheumatoid arthritis of the knee joint, showing mild inflammation and erosion of the joint surfaces',
#  'Knee joint with mild joint inflammation and minimal erosion',
#  'Joint inflammation causing swelling and deformity',
# ...

# %%
for value in common_list_of_prompts :
  if (('X-ray' not in value) or(')' in value)) :
    print(value)
    common_list_of_prompts.remove(value)
# Out:
# Joint inflammation causing mild swelling and deformity
# Rheumatoid arthritis of the knee joint, showing joint inflammation and erosion
# Knee joint with minimal joint inflammation and no erosion or deformity
# Normal knee joint:
# Rheumatoid arthritis of the knee joint, showing mild inflammation and erosion of the joint surfaces
# Joint inflammation causing swelling and deformity
# Inflammation of the knee joint, with erosion and deformity of the bones
# Joint inflammation
# Severe joint inflammation and erosion, with significant deformity
# Knee joint with mild inflammation and erosion
# Joint inflammation causing mild swelling and deformity
# Rheumatoid arthritis affecting the knee joint The joint is inflamed, eroded, and deformed
# (Degenerative joint disease caused by rheumatoid arthritis Source: https://radiopaediaorg/articles/rheumatoid-arthritis-1)
# Knee joint with mild inflammation and erosion
# Severe joint inflammation with severe erosion and deformity
# ...

# %%
len(common_list_of_prompts)
# Out:
# 108

# %%
common_list_of_prompts_clean = []
[common_list_of_prompts_clean.append(x) for x in common_list_of_prompts if x not in common_list_of_prompts_clean]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
common_list_of_prompts_clean
# Out:
# ['This X-ray shows a joint with moderate inflammation and some erosion The joint space is narrowed and the bones are deformed',
#  'This X-ray shows mild joint inflammation and erosion in the knee joint There is some deformity of the joint, but it is not severe',
#  'Joint inflammation:  There is swelling and inflammation around the joint, as well as deformity of the joint',
#  'Knee joint with mild joint inflammation and minimal erosion',
#  'Severe joint inflammation and extensive erosion of the bones, with severe deformity of the joint',
#  'Knee joint with moderate joint inflammation, erosion, and deformity The joint space is narrowed and there is evidence of bone marrow edema',
#  'Rheumatoid arthritis of the right knee, showing mild joint inflammation and erosion',
#  'Knee joint with moderate joint inflammation and erosion Annotation indicates specific features visible on X-ray',
# ...

# %%
len(common_list_of_prompts_clean)
# Out:
# 65

# %%
import pandas as pd
  

# Calling DataFrame constructor on list
df = pd.DataFrame(common_list_of_prompts)
df
# Out:
#                                                      0
# 0    This X-ray shows a joint with moderate inflamm...
# 1    This X-ray shows mild joint inflammation and e...
# 2    Joint inflammation:  There is swelling and inf...
# 3    Knee joint with mild joint inflammation and mi...
# 4    Severe joint inflammation and extensive erosio...
# ..                                                 ...
# 103  Knee joint with mild joint inflammation and er...
# 104                                Joint inflammation:
# 105
# 106  This X-ray shows a joint with mild inflammatio...
# 107  This X-ray shows a joint with mild inflammatio...
#
# [108 rows x 1 columns]

# %%
from google.colab import drive
drive.mount('drive')

df.to_csv('/content/drive/My Drive/prompt_five.csv', encoding='utf-8', index=False,mode='a')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
len(common_list_of_prompts_clean)
# Out:
# 65

# %%
for i in common_list_of_prompts:
  print(i)
# Out:
# This X-ray shows a joint with moderate inflammation and some erosion The joint space is narrowed and the bones are deformed
# This X-ray shows mild joint inflammation and erosion in the knee joint There is some deformity of the joint, but it is not severe
# Joint inflammation:  There is swelling and inflammation around the joint, as well as deformity of the joint
# Knee joint with mild joint inflammation and minimal erosion
# Severe joint inflammation and extensive erosion of the bones, with severe deformity of the joint
# Knee joint with moderate joint inflammation, erosion, and deformity The joint space is narrowed and there is evidence of bone marrow edema
# Rheumatoid arthritis of the right knee, showing mild joint inflammation and erosion
# Knee joint with moderate joint inflammation and erosion Annotation indicates specific features visible on X-ray
# This X-ray shows joint inflammation and erosion in the knee joint There is significant joint deformity visible in the image
# ...

# %% [markdown]
# ---
#
#
# **To send the prompt to generate images through API Calling using Dalle-2**
#
# ---

# %%
import requests
import json
import os
import random
import string
import argparse
import time
import json 
from requests import get

# %%
def download(url, file_name):
    # open in binary mode
    with open(file_name, "wb") as file:
        # get request
        response = get(url)
        # write to file
        file.write(response.content)

# %% [markdown]
# ---
# **Prompts and code for generating images with Knee Rheumatoid arthritis using dalle-2**
#
# ---

# %%
common_list_of_prompts[106:]
# Out:
# ['This X-ray shows a joint with mild inflammation, slight erosion, and some deformity',
#  'This X-ray shows a joint with mild inflammation and some erosion of the cartilage There is also some deformity of the joint, but it is not severe']

# %%
promptlist_two = [
    "Display an x-ray image of the knee joint of a person with rheumatoid arthritis, highlighting the areas of bone erosion, using stable diffusion.",
    "Using stable diffusion, show an x-ray image of the knee joint of a person with rheumatoid arthritis, focusing on the synovial thickening and joint space narrowing.",
    "Display an x-ray image of the lateral view of the knee joint of a person with rheumatoid arthritis, highlighting the presence of joint effusion, using stable diffusion.",
    "Using stable diffusion, show an x-ray image of the anterior-posterior view of the knee joint of a person with rheumatoid arthritis, emphasizing the presence of periarticular osteopenia.",
    "Display an x-ray image of the knee joint of a person with rheumatoid arthritis, highlighting the periarticular soft tissue swelling, using stable diffusion.",
    "show an x-ray image of the knee joint of a person with rheumatoid arthritis, emphasizing the presence of subchondral bone cysts.",
    "Display an x-ray image of the medial view of the knee joint of a person with rheumatoid arthritis, highlighting the osteophyte formation, using stable diffusion.",
    "show an x-ray image of the knee joint of a person with rheumatoid arthritis, focusing on the presence of subluxation or dislocation.",
    "Display an x-ray image of the posterior view of the knee joint of a person with rheumatoid arthritis, highlighting the loss of joint alignment, using stable diffusion.",
    "show an x-ray image of the knee joint of a person with rheumatoid arthritis, emphasizing the presence of joint space narrowing and bone deformity.",
    "Display an x-ray image of the knee joint of a person with rheumatoid arthritis, highlighting the presence of bone erosions and subchondral sclerosis, using stable diffusion.",
    "Using stable diffusion, show an x-ray image of the knee joint of a person with rheumatoid arthritis, emphasizing the periarticular osteoporosis and bony destruction.",
    "Display an x-ray image of the anterior-posterior view of the knee joint of a person with rheumatoid arthritis, highlighting the presence of joint subluxation, using stable diffusion.",
    "Using stable diffusion, show an x-ray image of the knee joint of a person with rheumatoid arthritis, emphasizing the presence of a narrowed joint space and marginal osteophytes.",
    "Display an x-ray image of the lateral view of the knee joint of a person with rheumatoid arthritis, highlighting the presence of joint effusion and synovial hypertrophy, using stable diffusion.",
    "show an x-ray image of the knee joint of a person with rheumatoid arthritis, emphasizing the presence of bone erosion and subchondral cysts.",
    "Display an x-ray image of the knee joint of a person with rheumatoid arthritis, highlighting the presence of subchondral sclerosis and osteophyte formation, using stable diffusion.",
    "show an x-ray image of the knee joint of a person with rheumatoid arthritis, emphasizing the presence of periarticular soft tissue swelling and bony destruction.",
    "Display an x-ray image of the anterior-posterior view of the knee joint of a person with rheumatoid arthritis, highlighting the presence of joint space narrowing and bone deformity, using stable diffusion."
]

# %%
for i, prompt_value in enumerate(promptlist_two):
  if((i!=0) and (i%5 == 0)):
    print("=======================================================")
    print("Taking rest for 65 secs")
    time.sleep(65) 
    print("=======================================================")

  print(f"\nStarted generating response for prompt value {i}")
  print(f"prompt value is {prompt_value}")
  response=openai.Image.create(
    prompt= prompt_value,
    n=1,
    size="256x256"
  )

  download(response['data'][0]["url"], f"rheumatoid_knee_arthritis_i_{i}.png")
  print(f"Downloaded prompt value for {i}")
# Out:
# Started generating response for prompt value 0
# prompt value is Display an x-ray image of the knee joint of a person with rheumatoid arthritis, highlighting the areas of bone erosion, using stable diffusion.
# Downloaded prompt value for 0
#
# Started generating response for prompt value 1
# prompt value is Using stable diffusion, show an x-ray image of the knee joint of a person with rheumatoid arthritis, focusing on the synovial thickening and joint space narrowing.
# Downloaded prompt value for 1
#
# Started generating response for prompt value 2
# prompt value is Display an x-ray image of the lateral view of the knee joint of a person with rheumatoid arthritis, highlighting the presence of joint effusion, using stable diffusion.
# Downloaded prompt value for 2
#
# Started generating response for prompt value 3
# ...

# %% [markdown]
# ---
# **Prompts and code for generating images with Healthy Knee images using dalle-2**
#
# ---

# %%
openai.api_key = "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"

# %%
# Define the starting prompt
#prompt = "Generate 10 unique prompts to display only X-ray images of people with knee rheumatoid arthritis. The images should show the knee joint with clear indications of rheumatoid arthritis. Please ensure that the images are of high quality and accurately represent the condition"
#prompt = "Generate 10 different prompts to display only X-ray images of children, men, and women with knee rheumatoid arthritis. The prompt must contain the word X-ray. The images should show the knee joint with clear indications of rheumatoid arthritis. Please ensure that the images are of high quality and accurately represent the condition"

#prompt = "Generate 10 unique prompts to display only X-ray images of people with rheumatoid arthritis on knee. The images should show the knee joint with clear indications of rheumatoid arthritis. Please ensure that the images are of high quality and accurately represent the condition"

#prompt = "Create a set of 10 realistic X-ray images using DALL-E 2 that depict different stages of knee rheumatoid arthritis in patients. Each image should show a different degree of joint inflammation, erosion, and deformity, as well as any associated changes in the surrounding tissues. Use annotations to indicate the specific features of each image, such as the presence of bone spurs, the loss of joint space, or the development of cysts. Consider including images that show the progression of the disease over time, as well as images that illustrate the variation in symptoms and severity that can occur between different patients."

#prompt ="Using DALL-E 2, create 10 realistic X-ray images of knee joints affected by rheumatoid arthritis. Show different degrees of joint inflammation, erosion, and deformity, with annotations to indicate specific features visible on an X-ray. Make the images as accurate and realistic as possible, displaying the internal structures of the knee joint."

prompt = "Generate 10 unique prompts to display only X-ray images of people with healthy knee.  Ensure that the images accurately depict healthy knee joints, with no signs of damage, injury, or disease. Vary the angles, positions, and lighting conditions to create diverse and realistic images. Experiment with adjusting the image resolution and quality to produce high-quality X-ray images. Use natural language prompts that clearly describe the desired images, such as 'an X-ray image of a healthy knee joint viewed from a 45-degree angle with bright overhead lighting'. Be sure to carefully review each generated image to ensure accuracy and quality."

# Define a list of image types
# image_types = ["a dog", "a cat", "a car", "a mountain", "a beach", "a city skyline",
#                "a forest", "a waterfall", "a flower garden", "a person"]

# Define the number of prompts to generate
num_prompts = 50

# Generate the prompts
prompts = []
for i in range(num_prompts):
    # Select a random image type from the list
    #image_type = image_types[random.randint(0, len(image_types)-1)]
    
    # Create the full prompt
    #full_prompt = prompt + image_type
    full_prompt = prompt
    
    # Use the OpenAI API to generate a text completion for the prompt
    response = openai.Completion.create(
        engine="text-davinci-002",
        prompt=full_prompt,
        max_tokens=1024,
        n=1,
        stop=None,
        temperature=0.7,
    )
    # Extract the generated text from the API response
    text = response.choices[0].text.strip()
    
    # Add the generated text to the list of prompts
    prompts.append(text)

# %%
common_list_of_prompts_healthy = []
for i,string in enumerate(prompts):
  tmp = re.sub(r'\d+\.', '||', string.replace('\n', ' ')).replace('.', '').strip()
  tmp = re.sub(r'^(\|{2})|(\|{2})$', '', tmp).strip().split('||')
  final_prompt = tmp[0].strip()
  common_list_of_prompts_healthy.append(final_prompt)

# %%
common_list_of_prompts_healthy
print(len(common_list_of_prompts_healthy))
# Out:
# 50

# %%
for value in common_list_of_prompts_healthy :
  if (('X-ray' not in value) or(')' in value)) :
    print(value)
    common_list_of_prompts_healthy.remove(value)

len(common_list_of_prompts)
# Out:
# 1) An X-ray image of a healthy knee joint viewed from a 45-degree angle with bright overhead lighting 2) An X-ray image of a healthy knee joint from the front, with the joint in a flexed position 3) An X-ray image of a healthy knee joint from the back, with the joint in a flexed position 4) A side view X-ray image of a healthy knee joint, with the joint in a neutral position 5) A side view X-ray image of a healthy knee joint, with the joint in a slightly bent position 6) An X-ray image of a healthy knee joint from the front, with the joint in a neutral position 7) An X-ray image of a healthy knee joint from the back, with the joint in a neutral position 8) A close-up X-ray image of a healthy knee joint, focusing on the area around the kneecap 9) A close-up X-ray image of a healthy knee joint, focusing on the area around the knee joint 10) An X-ray image of a healthy knee joint from the front, with the joint in a fully extended position
# 108

# %%
len(common_list_of_prompts_healthy)
# Out:
# 49

# %%
unique_prompts = list(filter(None, unique_prompts))
unique_prompts
# Out:
# [' An X-ray image of a healthy knee joint in motion, such as when bending or straightening the leg',
#  ' X-ray image of a healthy knee joint with soft, diffused lighting',
#  ' X-ray image of a healthy knee joint viewed from a 135-degree angle with dim overhead lighting',
#  ' A black and white X-ray image of a healthy knee joint viewed from a 90-degree angle',
#  ' A high-resolution X-ray image of a healthy knee joint viewed from a 45-degree angle with dim overhead lighting',
#  ' A high-resolution X-ray image of a healthy knee joint from a side view',
#  ' An X-ray image of a healthy knee joint viewed from a 90-degree angle with dim lighting',
#  ' An X-ray image of a healthy knee joint, viewed from a 90-degree angle, with natural lighting',
#  ' An X-ray image of a healthy knee joint viewed from a 270-degree angle with bright overhead lighting',
#  ' An X-ray image of a healthy knee joint viewed from a 45-degree angle with natural lighting',
# ...

# %%
# Calling DataFrame constructor on list
df = pd.DataFrame(common_list_of_prompts_healthy)
df
# Out:
#                                                     0
# 0   An X-ray image of a healthy knee joint viewed ...
# 1   An X-ray image of a healthy knee joint, viewed...
# 2   An X-ray image of a healthy knee joint viewed ...
# 3   An X-ray image of a healthy knee joint viewed ...
# 4   An X-ray image of a healthy knee joint viewed ...
# 5   An X-ray image of a healthy knee joint viewed ...
# 6   An X-ray image of a healthy knee joint viewed ...
# 7   An X-ray image of a healthy knee joint viewed ...
# 8   X-ray image of a healthy knee joint viewed fro...
# 9   An X-ray image of a healthy knee joint viewed ...
# 10  An X-ray image of a healthy knee joint viewed ...
# 11  An X-ray image of a healthy knee joint viewed ...
# 12  An X-ray image of a healthy knee joint viewed ...
# 13  An X-ray image of a healthy knee joint, viewed...
# 14  An X-ray image of a healthy knee joint viewed ...
# 15  An X-ray image of a healthy knee joint viewed ...
# ...

# %%
import pandas as pd
  

# Calling DataFrame constructor on list
df1 = pd.DataFrame(unique_prompts)

from google.colab import drive
drive.mount('drive')

df1.to_csv('/content/drive/My Drive/healthy_knee_prompt_two.csv', encoding='utf-8', index=False,mode='a')
df1
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).
#                                                      0
# 0
# 1     An X-ray image of a healthy knee joint in mot...
# 2     X-ray image of a healthy knee joint with soft...
# 3     X-ray image of a healthy knee joint viewed fr...
# 4     A black and white X-ray image of a healthy kn...
# ..                                                 ...
# 179   A close-up X-ray image of a healthy knee join...
# 180   An X-ray image of a healthy knee joint viewed...
# 181   An X-ray image of a healthy knee joint with t...
# 182   A close-up X-ray image of a healthy knee join...
# 183   An X-ray image of a healthy knee joint viewed...
#
# [184 rows x 1 columns]

# %%
from google.colab import drive
drive.mount('drive')

df.to_csv('/content/drive/My Drive/healthy_knee_prompt.csv', encoding='utf-8', index=False,mode='a')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %% [markdown]
# ---
#
#
# **To send the prompt to generate Healthy images through API Calling using Dalle-2**
#
# ---

# %%
import requests
import json
import os
import random
import string
import argparse
import time
import json 
from requests import get

# %%
def download(url, file_name):
    # open in binary mode
    with open(file_name, "wb") as file:
        # get request
        response = get(url)
        # write to file
        file.write(response.content)

# %%
for i, prompt_value in enumerate(unique_prompts):
  if((i!=0) and (i%5 == 0)):
    print("=======================================================")
    print("Taking rest for 65 secs")
    time.sleep(65) 
    print("=======================================================")

  print(f"\nStarted generating response for prompt value {i}")
  print(f"prompt value is {prompt_value}")
  response=openai.Image.create(
    prompt= prompt_value,
    n=1,
    size="256x256"
  )

  download(response['data'][0]["url"], f"healthy_knee_b_{i}.png")
  print(f"Downloaded prompt value for {i}")
# Out:
# Started generating response for prompt value 0
# prompt value is  An X-ray image of a healthy knee joint in motion, such as when bending or straightening the leg
# Downloaded prompt value for 0
#
# Started generating response for prompt value 1
# prompt value is  X-ray image of a healthy knee joint with soft, diffused lighting
# Downloaded prompt value for 1
#
# Started generating response for prompt value 2
# prompt value is  X-ray image of a healthy knee joint viewed from a 135-degree angle with dim overhead lighting
# Downloaded prompt value for 2
#
# Started generating response for prompt value 3
# prompt value is  A black and white X-ray image of a healthy knee joint viewed from a 90-degree angle
# Downloaded prompt value for 3
#
# Started generating response for prompt value 4
# prompt value is  A high-resolution X-ray image of a healthy knee joint viewed from a 45-degree angle with dim overhead lighting
# Downloaded prompt value for 4
# ...
# Taking rest for 65 secs
# ...
#
# ...

# %% [markdown]
# ---
#
#
# **To send the prompt to generate images through API Calling using Stable Difusion**
#
# ---

# %%
url = "https://stablediffusionapi.com/api/v3/text2img"

# %%
common_list_of_prompts_chatgpt=["A realistic x-ray image of a person's knee with rheumatoid arthritis",
    "A knee x-ray showing advanced rheumatoid arthritis",
    "A realistic x-ray of a knee with severe rheumatoid arthritis",
    "A person's knee x-ray with rheumatoid arthritis and joint deformity",
    "An x-ray image of a knee with rheumatoid arthritis and bone erosion",
    "A knee x-ray with visible signs of rheumatoid arthritis progression",
    "An x-ray image of a person's knee with advanced rheumatoid arthritis and joint damage",
    "A realistic x-ray image of a knee with rheumatoid arthritis and inflammation",
    "A person's knee x-ray with rheumatoid arthritis and joint stiffness",\
    "An x-ray image of a knee with rheumatoid arthritis and joint space narrowi"]

# %%
promptlist_two = [
    "Display an x-ray image of the knee joint of a person with rheumatoid arthritis, highlighting the areas of bone erosion, using stable diffusion.",
    "Using stable diffusion, show an x-ray image of the knee joint of a person with rheumatoid arthritis, focusing on the synovial thickening and joint space narrowing.",
    "Display an x-ray image of the lateral view of the knee joint of a person with rheumatoid arthritis, highlighting the presence of joint effusion, using stable diffusion.",
    "Using stable diffusion, show an x-ray image of the anterior-posterior view of the knee joint of a person with rheumatoid arthritis, emphasizing the presence of periarticular osteopenia.",
    "Display an x-ray image of the knee joint of a person with rheumatoid arthritis, highlighting the periarticular soft tissue swelling, using stable diffusion.",
    "show an x-ray image of the knee joint of a person with rheumatoid arthritis, emphasizing the presence of subchondral bone cysts.",
    "Display an x-ray image of the medial view of the knee joint of a person with rheumatoid arthritis, highlighting the osteophyte formation, using stable diffusion.",
    "show an x-ray image of the knee joint of a person with rheumatoid arthritis, focusing on the presence of subluxation or dislocation.",
    "Display an x-ray image of the posterior view of the knee joint of a person with rheumatoid arthritis, highlighting the loss of joint alignment, using stable diffusion.",
    "show an x-ray image of the knee joint of a person with rheumatoid arthritis, emphasizing the presence of joint space narrowing and bone deformity.",
    "Display an x-ray image of the knee joint of a person with rheumatoid arthritis, highlighting the presence of bone erosions and subchondral sclerosis, using stable diffusion.",
    "Using stable diffusion, show an x-ray image of the knee joint of a person with rheumatoid arthritis, emphasizing the periarticular osteoporosis and bony destruction.",
    "Display an x-ray image of the anterior-posterior view of the knee joint of a person with rheumatoid arthritis, highlighting the presence of joint subluxation, using stable diffusion.",
    "Using stable diffusion, show an x-ray image of the knee joint of a person with rheumatoid arthritis, emphasizing the presence of a narrowed joint space and marginal osteophytes.",
    "Display an x-ray image of the lateral view of the knee joint of a person with rheumatoid arthritis, highlighting the presence of joint effusion and synovial hypertrophy, using stable diffusion.",
    "show an x-ray image of the knee joint of a person with rheumatoid arthritis, emphasizing the presence of bone erosion and subchondral cysts.",
    "Display an x-ray image of the knee joint of a person with rheumatoid arthritis, highlighting the presence of subchondral sclerosis and osteophyte formation, using stable diffusion.",
    "show an x-ray image of the knee joint of a person with rheumatoid arthritis, emphasizing the presence of periarticular soft tissue swelling and bony destruction.",
    "Display an x-ray image of the anterior-posterior view of the knee joint of a person with rheumatoid arthritis, highlighting the presence of joint space narrowing and bone deformity, using stable diffusion."
]

# %%
for i, prompt in enumerate(promptlist_two[:5]):
  print(f"\nStarted generating response for prompt value {i}")
  print(f"Generating response for prompt {i+1}")
  print(f"prompt value is --> {prompt}")
  payload = json.dumps({
  "key": "pVpYOg0B3fPrRGnCpuIcVz7FPYUAYy3GQSaOGJSrWpIsUsvw5ApmywfAagyp",
  "model-id": "midjourney",
  "prompt": "Using DALL-E 2, generate unique X-ray images of people with healthy knees. Ensure that the images depict clear and accurate representations of healthy knee joints, with no signs of damage, injury or disease. Use a variety of different angles, positions and lighting conditions to create realistic and diverse images. Adjust the image resolution and quality as needed to produce high-quality X-ray images."
,
  "width": "256",
  "height": "256",
  "samples": "1",
  "num_inference_steps": "20",
  "seed": "None",
  "guidance_scale": 7.5,
  "safety_checker": "yes",
  "webhook": "None",
  "track_id": "None"
  })
  headers = {
  'Content-Type': 'application/json'
    }


  response = requests.request("POST", url, headers=headers, data=payload)
  print(response)

  json_val= json.loads(response.text)
  download(json_val['output'][0], f"rheumatoid_knee_arthritis_i_{i}.png") 
  print(f"Downloaded prompt value for {i}")
  print("=======================================================")
  print("Taking rest for 33 secs")
  time.sleep(33) 
  print("=======================================================")
  
  # filename = f"response_{i+1}_{random.randint(0, 1000000)}.jpg"

  # # Download the image from the response and save it to a file
  # with open(filename, "wb") as f:
  #   f.write(response.content)
    
  # # Wait for 33 seconds before sending the next request (API rate limit)
  # time.sleep(33) 
    # headers = {
    # 'Content-Type': 'application/json'
    # }
# Out:
# Started generating response for prompt value 0
# Generating response for prompt 1
# prompt value is --> Display an x-ray image of the knee joint of a person with rheumatoid arthritis, highlighting the areas of bone erosion, using stable diffusion.
# <Response [200]>
# Downloaded prompt value for 0
# ...
# Taking rest for 33 secs
# ...
#
# Started generating response for prompt value 1
# Generating response for prompt 2
# prompt value is --> Using stable diffusion, show an x-ray image of the knee joint of a person with rheumatoid arthritis, focusing on the synovial thickening and joint space narrowing.
# <Response [200]>
# Downloaded prompt value for 1
# ...
# Taking rest for 33 secs
# ...
#
# Started generating response for prompt value 2
# Generating response for prompt 3
# prompt value is --> Display an x-ray image of the lateral view of the knee joint of a person with rheumatoid arthritis, highlighting the presence of joint effusion, using stable diffusion.
# <Response [200]>
# ...

# %% [markdown]
# ---
# **Generate images of a Healthy knee using Stable diffusion**
#
# ---

# %%
for i in range(0,10):
  print(f"\nStarted generating response for prompt value {i}")
  print(f"Generating response for prompt {i+1}")
  #print(f"prompt value is --> {prompt}")
  payload = json.dumps({
  "key": "pVpYOg0B3fPrRGnCpuIcVz7FPYUAYy3GQSaOGJSrWpIsUsvw5ApmywfAagyp",
  "model-id": "midjourney",
  "prompt": "Using DALL-E 2, generate unique X-ray images of people with healthy knees. Ensure that the images depict clear and accurate representations of healthy knee joints, with no signs of damage, injury or disease. Use a variety of different angles, positions and lighting conditions to create realistic and diverse images. Adjust the image resolution and quality as needed to produce high-quality X-ray images."
,
  "width": "256",
  "height": "256",
  "samples": "1",
  "num_inference_steps": "20",
  "seed": "None",
  "guidance_scale": 7.5,
  "safety_checker": "yes",
  "webhook": "None",
  "track_id": "None"
  })
  headers = {
  'Content-Type': 'application/json'
    }


  response = requests.request("POST", url, headers=headers, data=payload)
  print(response)

  json_val= json.loads(response.text)
  download(json_val['output'][0], f"healthy_knee_a_{i}.png") 
  print(f"Downloaded prompt value for {i}")
  print("=======================================================")
  print("Taking rest for 33 secs")
  time.sleep(33) 
  print("=======================================================")
  
  # filename = f"response_{i+1}_{random.randint(0, 1000000)}.jpg"

  # # Download the image from the response and save it to a file
  # with open(filename, "wb") as f:
  #   f.write(response.content)
    
  # # Wait for 33 seconds before sending the next request (API rate limit)
  # time.sleep(33) 
    # headers = {
    # 'Content-Type': 'application/json'
    # }
# Out:
# Started generating response for prompt value 0
# Generating response for prompt 1
# <Response [200]>
# Downloaded prompt value for 0
# ...
# Taking rest for 33 secs
# ...
#
# Started generating response for prompt value 1
# Generating response for prompt 2
# <Response [200]>
# Downloaded prompt value for 1
# ...
# Taking rest for 33 secs
# ...
#
# Started generating response for prompt value 2
# Generating response for prompt 3
# <Response [200]>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-55-df15fe46c3a3> in <cell line: 1>()
#      27
#      28   json_val= json.loads(response.text)
# ---> 29   download(json_val['output'][0], f"healthy_knee_a_{i}.png")
#      30   print(f"Downloaded prompt value for {i}")
#      31   print("=======================================================")
#
# IndexError: string index out of range

# %% [markdown]
# ----
#
# 1. The results generated using stable disffusion did not give me the desired image. I will have to work on the same and check for better models to generate X-ray images.
#
# ----
